# %%
import pandas as pd

# %%
restaurants = pd.read_csv('restaurants.csv')
restaurants
# Out:
#                           name         image        type  \
# 0                      Le Dhow   image_url_1  Restaurant
# 1                     Ty Potes   image_url_2  Restaurant
# 2                     Dar Naji   image_url_3  Restaurant
# 3                  Rick's Café   image_url_4  Restaurant
# 4                     La Sqala   image_url_5  Restaurant
# 5                  Le Cabestan   image_url_6  Restaurant
# 6              El Morocco Club   image_url_7  Restaurant
# 7         Le Saveur du Poisson   image_url_8  Restaurant
# 8       Restaurant Rif Kebdani   image_url_9  Restaurant
# 9       Restaurant Al Akhawayn  image_url_10  Restaurant
# 10           Forest Restaurant  image_url_11  Restaurant
# 11                 Le Chamonix  image_url_12  Restaurant
# 12                  Café Clock  image_url_13  Restaurant
# 13           The Ruined Garden  image_url_14  Restaurant
# 14                 Dar Roumana  image_url_15  Restaurant
# ...
