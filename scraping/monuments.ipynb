# %%
import pandas as pd

# %%
df_cities = pd.read_csv('cities.csv')
df_monuments = pd.read_csv('monuments_data.csv')
df_monuments_description = pd.read_csv('monuments_description.csv')

# %%
df_monuments['type'] = 'Monument'
df_monuments['description'] = ''
df_monuments['rating'] = None
df_monuments['sponsored'] = False
df_monuments['schedule'] = None

# %%
df_monuments.drop(columns=['identifier', 'history'], inplace=True)

# %%
# count monuments by city
df_monuments['city'].value_counts()
# Out:
# city
# Meknes         79
# Rabat          72
# Marrakesh      54
# Fez            52
# Salé           29
# Essaouira      26
# El Jadida      24
# Tangier        13
# Safi           12
# Ouarzazate     10
# Casablanca      9
# Oujda           9
# Agadir          6
# Mehdya          5
# Chefchaouen     5
# Azilal          5
# Guelmim         4
# Figuig          4
# Errachidia      4
# El Hajeb        4
# Taroudant       4
# Zagora          4
# Asilah          3
# Nador           3
# Sidi Kacem      3
# Sidi Ifni       3
# Name: count, dtype: int64

# %%
df_monuments.loc[df_monuments['city'] == 'Marrakesh', 'city'] = 'Marrakech'

# %%
# get cities in cities.csv
cities = df_cities['city'].unique()
cities
# Out:
# array(['Rabat', 'Casablanca', 'Tangier', 'Ifrane', 'Fez', 'Dakhla',
#        'Marrakech', 'Meknes', 'Safi', 'Chefchaouen'], dtype=object)

# %%
# filter monuments by city
df_monuments_filtered = df_monuments[df_monuments['city'].isin(cities)]
df_monuments_filtered['city'].value_counts()
# Out:
# city
# Meknes         79
# Rabat          72
# Marrakech      54
# Fez            52
# Tangier        13
# Safi           12
# Casablanca      9
# Chefchaouen     5
# Name: count, dtype: int64

# %%
# add Ifrane
df_monuments_filtered = df_monuments_filtered._append({'city': 'Ifrane',
                                                       'image': '',
                                                       'name': '',
                                                       'location': 'Ifrane, Morocco',
                                                      'coordinates': '33.5245, -5.1102',
                                                      'type': 'Monument',
                                                      'description': '',
                                                      'rating': None,
                                                      'sponsored': False,
                                                      'schedule': None},
                                                     ignore_index=True)

# %%
# count null coordinates by city
df_monuments_filtered[df_monuments_filtered['coordinates'].isnull()]['city'].value_counts()
# Out:
# city
# Meknes         15
# Fez            12
# Rabat          10
# Marrakech       6
# Safi            2
# Tangier         2
# Chefchaouen     1
# Name: count, dtype: int64

# %%
# drop monuments with null coordinates
df_monuments_filtered_clean = df_monuments_filtered.dropna(subset=['coordinates'])
df_monuments_filtered_clean['city'].value_counts()
# Out:
# city
# Meknes         64
# Rabat          62
# Marrakech      48
# Fez            40
# Tangier        11
# Safi           10
# Casablanca      9
# Chefchaouen     4
# Ifrane          1
# Name: count, dtype: int64

# %%
# choose maximumn 10 monuments per city 
df_monuments_filtered_clean = df_monuments_filtered_clean.groupby('city').head(10)
df_monuments_filtered_clean['city'].value_counts()
# Out:
# city
# Fez            10
# Marrakech      10
# Meknes         10
# Rabat          10
# Safi           10
# Tangier        10
# Casablanca      9
# Chefchaouen     4
# Ifrane          1
# Name: count, dtype: int64

# %%
df_monuments_filtered_clean
# Out:
#            city                                              image  \
# 0    Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# 1    Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# 2    Casablanca                                                NaN
# 3    Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# 4    Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# ..          ...                                                ...
# 289     Tangier                                                NaN
# 290     Tangier                                                NaN
# 291     Tangier  https://upload.wikimedia.org/wikipedia/commons...
# 294     Tangier  https://upload.wikimedia.org/wikipedia/commons...
# 296      Ifrane
#
#                                     name         location  \
# 0                   Casablanca Cathedral       Casablanca
# 1                     El Hank Lighthouse       Casablanca
# 2           Notre-Dame-de-Lourdes Church       Casablanca
# 3         Arab League Park of Casablanca       Casablanca
# 4                            Isesco Park       Casablanca
# ..                                   ...              ...
# 289                        Borj Es-Salam          Tangier
# 290           Abraham Toledano Synagogue          Tangier
# 291  Church of the Immaculate Conception          Tangier
# 294                Bab El Bhar (Tangier)          Tangier
# 296                                       Ifrane, Morocco
#
#                        coordinates      type description rating  sponsored  \
# 0            33°35'28"N, 7°37'28"W  Monument               None      False
# 1      33°36'35.71"N, 7°39'16.81"W  Monument               None      False
# 2        33°34'57.5"N, 7°36'56.8"W  Monument               None      False
# 3    33°35'15.846"N, 7°37'28.668"W  Monument               None      False
# 4    33°34'45.988"N, 7°36'47.722"W  Monument               None      False
# ..                             ...       ...         ...    ...        ...
# 289  35°47'13.664"N, 5°48'34.186"W  Monument               None      False
# 290   35°47'6.428"N, 5°48'42.574"W  Monument               None      False
# 291           35°47'7"N, 5°48'41"W  Monument               None      False
# 294  35°47'20.429"N, 5°48'43.610"W  Monument               None      False
# 296               33.5245, -5.1102  Monument               None      False
#
#     schedule
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ..       ...
# 289     None
# 290     None
# 291     None
# 294     None
# 296     None
#
# [74 rows x 10 columns]

# %%
# add monuments description
df_monuments_filtered_clean = df_monuments_filtered_clean.merge(df_monuments_description, on='name', how='left')
df_monuments_filtered_clean['description_x'] = df_monuments_filtered_clean['description_y']
df_monuments_filtered_clean.drop(columns='description_y', inplace=True)
df_monuments_filtered_clean.rename(columns={'description_x': 'description'}, inplace=True)
df_monuments_filtered_clean
# Out:
#           city                                              image  \
# 0   Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# 1   Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# 2   Casablanca                                                NaN
# 3   Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# 4   Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# ..         ...                                                ...
# 69     Tangier                                                NaN
# 70     Tangier                                                NaN
# 71     Tangier  https://upload.wikimedia.org/wikipedia/commons...
# 72     Tangier  https://upload.wikimedia.org/wikipedia/commons...
# 73      Ifrane
#
#                                    name         location  \
# 0                  Casablanca Cathedral       Casablanca
# 1                    El Hank Lighthouse       Casablanca
# 2          Notre-Dame-de-Lourdes Church       Casablanca
# 3        Arab League Park of Casablanca       Casablanca
# 4                           Isesco Park       Casablanca
# ..                                  ...              ...
# 69                        Borj Es-Salam          Tangier
# 70           Abraham Toledano Synagogue          Tangier
# 71  Church of the Immaculate Conception          Tangier
# 72                Bab El Bhar (Tangier)          Tangier
# 73                                       Ifrane, Morocco
#
#                       coordinates      type  \
# 0           33°35'28"N, 7°37'28"W  Monument
# 1     33°36'35.71"N, 7°39'16.81"W  Monument
# 2       33°34'57.5"N, 7°36'56.8"W  Monument
# 3   33°35'15.846"N, 7°37'28.668"W  Monument
# 4   33°34'45.988"N, 7°36'47.722"W  Monument
# ..                            ...       ...
# 69  35°47'13.664"N, 5°48'34.186"W  Monument
# 70   35°47'6.428"N, 5°48'42.574"W  Monument
# 71           35°47'7"N, 5°48'41"W  Monument
# 72  35°47'20.429"N, 5°48'43.610"W  Monument
# 73               33.5245, -5.1102  Monument
#
#                                           description rating  sponsored  \
# 0   Also known as the Sacré-Cœur Cathedral, this s...   None      False
# 1   Built in 1916, this lighthouse stands at 51 me...   None      False
# 2   Notable for its modernist architecture and imp...   None      False
# 3   A large urban park established in 1918, featur...   None      False
# 4   Named after the Islamic Educational, Scientifi...   None      False
# ..                                                ...    ...        ...
# 69  A historic fortification in Tangier, notable f...   None      False
# 70  A historic synagogue in Tangier, reflecting th...   None      False
# 71  A Catholic church in Tangier, known for its ar...   None      False
# 72  A historic gate in Tangier, part of the city's...   None      False
# 73                                                NaN   None      False
#
#    schedule
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ..      ...
# 69     None
# 70     None
# 71     None
# 72     None
# 73     None
#
# [74 rows x 10 columns]

# %%
# add random rating between 3 and 5, 2 decimal places
import random
df_monuments_filtered_clean['rating'] = df_monuments_filtered_clean['rating'].apply(lambda x: round(random.uniform(3, 5), 2))
# change type to float
df_monuments_filtered_clean['rating'] = df_monuments_filtered_clean['rating'].astype(float)
df_monuments_filtered_clean
# Out:
#           city                                              image  \
# 0   Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# 1   Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# 2   Casablanca                                                NaN
# 3   Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# 4   Casablanca  https://upload.wikimedia.org/wikipedia/commons...
# ..         ...                                                ...
# 69     Tangier                                                NaN
# 70     Tangier                                                NaN
# 71     Tangier  https://upload.wikimedia.org/wikipedia/commons...
# 72     Tangier  https://upload.wikimedia.org/wikipedia/commons...
# 73      Ifrane
#
#                                    name         location  \
# 0                  Casablanca Cathedral       Casablanca
# 1                    El Hank Lighthouse       Casablanca
# 2          Notre-Dame-de-Lourdes Church       Casablanca
# 3        Arab League Park of Casablanca       Casablanca
# 4                           Isesco Park       Casablanca
# ..                                  ...              ...
# 69                        Borj Es-Salam          Tangier
# 70           Abraham Toledano Synagogue          Tangier
# 71  Church of the Immaculate Conception          Tangier
# 72                Bab El Bhar (Tangier)          Tangier
# 73                                       Ifrane, Morocco
#
#                       coordinates      type  \
# 0           33°35'28"N, 7°37'28"W  Monument
# 1     33°36'35.71"N, 7°39'16.81"W  Monument
# 2       33°34'57.5"N, 7°36'56.8"W  Monument
# 3   33°35'15.846"N, 7°37'28.668"W  Monument
# 4   33°34'45.988"N, 7°36'47.722"W  Monument
# ..                            ...       ...
# 69  35°47'13.664"N, 5°48'34.186"W  Monument
# 70   35°47'6.428"N, 5°48'42.574"W  Monument
# 71           35°47'7"N, 5°48'41"W  Monument
# 72  35°47'20.429"N, 5°48'43.610"W  Monument
# 73               33.5245, -5.1102  Monument
#
#                                           description  rating  sponsored  \
# 0   Also known as the Sacré-Cœur Cathedral, this s...    3.98      False
# 1   Built in 1916, this lighthouse stands at 51 me...    3.32      False
# 2   Notable for its modernist architecture and imp...    4.52      False
# 3   A large urban park established in 1918, featur...    4.93      False
# 4   Named after the Islamic Educational, Scientifi...    4.87      False
# ..                                                ...     ...        ...
# 69  A historic fortification in Tangier, notable f...    3.79      False
# 70  A historic synagogue in Tangier, reflecting th...    4.19      False
# 71  A Catholic church in Tangier, known for its ar...    3.00      False
# 72  A historic gate in Tangier, part of the city's...    4.87      False
# 73                                                NaN    4.15      False
#
#    schedule
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ..      ...
# 69     None
# 70     None
# 71     None
# 72     None
# 73     None
#
# [74 rows x 10 columns]

# %%
df_monuments_filtered_clean.to_csv('monuments.csv', index=False)
